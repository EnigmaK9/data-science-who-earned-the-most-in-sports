# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("forbes-richest-athletes.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-be34faab1894> in <module>()
# ----> 1 df = pd.read_csv("forbes-richest-athletes.csv")
#       2 df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df1 = df.copy()
df1.drop('S.NO',axis=1,inplace=True)
df1.head()
# Out:
#                 Name Nationality  Current Rank Previous Year Rank  \
# 0         Mike Tyson         USA             1                NaN
# 1     Buster Douglas         USA             2                NaN
# 2  Sugar Ray Leonard         USA             3                NaN
# 3       Ayrton Senna      Brazil             4                NaN
# 4        Alain Prost      France             5                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# 3  auto racing  1990                  10.0
# 4  auto racing  1990                   9.0

# %% [markdown]
# ## Renombrar columnas por comodidad

# %%
df.rename(columns = {'Index':'index', 'Name':'name', 'Nationality':'nationality',
'Current Rank': 'current-rank', 'Previous Year Rank': 'previous-year-rank', 'Sport':'sport',
'Year':'year', 'earnings ($ million)':'earnings'}, inplace = True)

# %% [markdown]
# # 1. Deportistas cuyo ranking ha subido al menos dos lugares entre 2010 y 2020.

# %%
# 
r2010_2020 = df[df["year"] >= 2010]
# Pandas tail() method is used to return bottom n (5 by default) rows of a data frame or series.
r2010_2020.tail(6)
# Out:
#      S.NO           name nationality  current-rank previous-year-rank  \
# 295   296   LeBron James         USA             5                  8
# 296   297  Stephen Curry         USA             6                  9
# 297   298   Kevin Durant         USA             7                 10
# 298   299    Tiger Woods         USA             8                 11
# 299   300   Kirk Cousins         USA             9               >100
# 300   301   Carson Wentz         USA            10               >100
#
#                  sport  year  earnings
# 295         Basketball  2020      88.2
# 296         Basketball  2020      74.4
# 297         Basketball  2020      63.9
# 298               Golf  2020      62.3
# 299  American Football  2020      60.5
# 300  American Football  2020      59.1

# %% [markdown]
# # 2.Atleta con el menor número de apariciones y mayores ganancias.

# %% [markdown]
# ### Número de atletas en el conjunto de datos.

# %%
len(set(r2010_2020['name']))
# Out:
# 36

# %% [markdown]
# ### Número de apariciones de los atletas en la lista

# %%
# number of times a name appears on the top payed list

athletes2010_2020 = pd.DataFrame(r2010_2020["name"].value_counts())
athletes2010_2020.tail(22)
# Out:
#                     name
# Matthew Stafford       1
# Eli Manning            1
# Cam Newton             1
# Kirk Cousins           1
# Alex Rodriguez         1
# Aaron Rogers           1
# Drew Brees             1
# Canelo Alvarez         1
# Novak Djokovic         1
# Terrell Suggs          1
# Lewis Hamilton         1
# James Harden           1
# Carson Wentz           1
# Peyton Manning         1
# Rory McIlroy           1
# Conor McGregor         1
# Rafael Nadal           1
# Jordan Spieth          1
# Russell Wilson         1
# Andrew Luck            1
# Aaron Rodgers          1
# Michael Schumacher     1

# %% [markdown]
# # Falta determinar quien de estos gana más

# %% [markdown]
# # 3. Deporte y país con mayor número de atletas no rankeados que entraron en la lista de atletas mejor pagados.

# %%
#Filtering athletes by previous year rank = NaN
not_ranked_athletes = df[df["previous-year-rank"].isna()]
# Sorting those values by desc and showing the top cut
not_ranked_athletes
# Out:
#      S.NO                name nationality  current-rank previous-year-rank  \
# 0       1          Mike Tyson         USA             1                NaN
# 1       2      Buster Douglas         USA             2                NaN
# 2       3   Sugar Ray Leonard         USA             3                NaN
# 3       4        Ayrton Senna      Brazil             4                NaN
# 4       5         Alain Prost      France             5                NaN
# 5       6       Jack Nicklaus         USA             6                NaN
# 6       7         Greg Norman   Australia             7                NaN
# 7       8      Michael Jordan         USA             8                NaN
# 8       9       Arnold Palmer         USA             8                NaN
# 9      10   Evander Holyfield         USA             8                NaN
# 80     81      Michael Jordan         USA             1                NaN
# ...

# %%
dnr = dataframe_not_ranked = not_ranked_athletes.groupby(["sport"]).earnings.sum().reset_index()
dnr
# Out:
#                 sport  earnings
# 0   American Football      50.0
# 1            Baseball      17.2
# 2          Basketball     202.8
# 3              Boxing      18.5
# 4      F1 Motorsports      38.0
# 5                Golf      44.9
# 6          Ice Hockey      29.8
# 7              NASCAR      24.1
# 8         auto racing      65.0
# 9          basketball       8.1
# 10             boxing      75.7
# 11               golf      25.2

# %% [markdown]
# ### Respuesta: Basketball/USA con 202.8M

# %% [markdown]
# # 4. País con mayor número de deportes con atletas en el conjunto de datos.

# %%
dfmaps = data_frame_most_athletes_per_sport = df['nationality'].value_counts()
dfmaps
# Out:
# USA                 206
# UK                   13
# Germany              13
# Switzerland          12
# Portugal             10
# Brazil                9
# Argentina             9
# Canada                6
# Italy                 4
# Finland               3
# Philippines           3
# France                3
# Serbia                1
# Dominican             1
# Australia             1
# Northern Ireland      1
# Spain                 1
# Ireland               1
# Austria               1
# Filipino              1
# Mexico                1
# Russia                1
# Name: nationality, dtype: int64

# %% [markdown]
# ### Respuesta: USA

# %% [markdown]
# # 5. ¿Cuántas atletas por deporte tiene cada país?

# %%
count_by_country = df.drop_duplicates("name")
count_by_country = count_by_country.groupby(["nationality","sport"]).size().reset_index(name = "count_by_country")
count_by_country.to_excel("count_by_country.xlsx")

# %% [markdown]
# # 6. Ganancia mínima y máxima (dentro del conjunto de datos) por deporte y por país.

# %% [markdown]
# # 7. Atleta con mayores ganancias por deporte por década

# %%
decade_1990 = df[df["year"] < 2000] 
decade_2000 = df[(df["year"] >= 2000) & (df["year"] < 2010)]
decade_2010 = df[df["year"] >= 2010]

# %%
decade_1990.sort_values(by = "earnings", ascending = False).head(1)
# Out:
#     S.NO            name nationality  current-rank previous-year-rank  \
# 70    71  Michael Jordan         USA             1                  2
#
#          sport  year  earnings
# 70  Basketball  1997      78.3

# %%
decade_2000.sort_values(by = "earnings", ascending = False).head(1)
# Out:
#      S.NO         name nationality  current-rank previous-year-rank sport  \
# 171   172  Tiger Woods         USA             1                  1  golf
#
#      year  earnings
# 171  2008     115.0

# %%
decade_2010.sort_values(by = "earnings", ascending = False).head(1)
# Out:
#      S.NO              name nationality  current-rank previous-year-rank  \
# 241   242  Floyd Mayweather         USA             1                  1
#
#       sport  year  earnings
# 241  Boxing  2015     300.0

# %% [markdown]
# # 8. Ganancia total por cada deporte por cada año.

# %%
dpspy = dataframe_per_sport_per_year = df.groupby(['sport','year']).earnings.sum()

dpspy.to_excel('earnings_per_sport_per_year.xlsx')
